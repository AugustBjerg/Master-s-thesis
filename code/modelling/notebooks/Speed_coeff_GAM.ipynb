# %% [markdown]
# # 1. Loading

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from loguru import logger
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from sklearn.impute import SimpleImputer
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error, root_mean_squared_error
from sklearn.model_selection import KFold, TimeSeriesSplit, train_test_split, cross_validate
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from pygam import LinearGAM, s, l, te
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.utils.validation import check_is_fitted

random_seed = 42

# %%
TIME_SPLIT = False

# %%
WINDOW_LENGTH = "5min"

# %%
notebook_dir = os.getcwd()
notebook_parent_dir = os.path.dirname(notebook_dir)
notebook_parent_parent_dir = os.path.dirname(notebook_parent_dir)
engineered_data_path = os.path.join(notebook_parent_parent_dir, 'data', 'engineered', f'engineered_features_{WINDOW_LENGTH}.csv')

# %%
df = pd.read_csv(engineered_data_path)
df["window_start"] = pd.to_datetime(df["window_start"], format='ISO8601', utc=True)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 47597 entries, 0 to 47596
# Data columns (total 57 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   seg_id                                                                 47597 non-null  int64
#  1   window_start                                                           47597 non-null  datetime64[us, UTC]
#  2   Vessel Hull Over Ground Speed (knots)                                  47597 non-null  float64
#  3   Vessel Hull Through Water Longitudinal Speed (knots)                   47597 non-null  float64
#  4   Vessel External Conditions Wind Relative Speed (knots)                 47597 non-null  float64
#  5   Vessel External Conditions Wind Relative Angle (degrees)               47597 non-null  float64
#  6   Vessel Hull Heading True Angle (degrees)                               47597 non-null  float64
#  7   Vessel Hull Heading Turn Rate (deg/min)                                47597 non-null  float64
#  8   Main Engine Turbocharger Rotational Speed (rpm)                        47597 non-null  float64
#  9   Main Engine Scavenging Air Pressure (bar)                              47597 non-null  float64
#  10  Main Engine Fuel Load % (%)                                            47597 non-null  float64
#  11  Main Engine Rotational Speed (rpm)                                     47597 non-null  float64
#  12  Vessel Propeller Shaft Torque (N*m)                                    47597 non-null  float64
#  13  Vessel Propeller Shaft Mechanical Power (KW)                           47597 non-null  float64
#  14  Main Engine Fuel Oil Inlet Mass Flow (kg/hr)                           47597 non-null  float64
#  15  Vessel Propeller Shaft Mechanical Energy (KWh)                         47597 non-null  float64
#  16  Vessel Propeller Shaft Thrust Force (KN)                               47597 non-null  float64
#  17  Vessel Propeller Shaft Rotational Speed (rpm)                          47597 non-null  float64
#  18  Vessel Propeller Shaft Revolutions (cumulative) (revs)                 47597 non-null  float64
#  19  Sea Temperature Dropout                                                47597 non-null  int64
#  20  Calculated Shaft Power                                                 47597 non-null  float64
#  21  Imputed Spike in Main Engine Rotational Speed                          47597 non-null  int64
#  22  Imputed Spike in Vessel External Conditions Wind Relative Speed        47597 non-null  int64
#  23  Imputed Spike in Vessel External Conditions Wind Relative Angle        47597 non-null  int64
#  24  Imputed Spike in Vessel Hull Over Ground Speed                         47597 non-null  int64
#  25  Imputed Spike in Vessel Hull Heading Turn Rate                         47597 non-null  int64
#  26  Imputed Spike in Vessel Hull Heading True Angle                        47597 non-null  int64
#  27  Imputed Spike in Main Engine Turbocharger Rotational Speed             47597 non-null  int64
#  28  Imputed Spike in Vessel Hull Through Water Longitudinal Speed          47597 non-null  int64
#  29  Imputed Spike in Main Engine Fuel Oil Inlet Mass Flow                  47597 non-null  int64
#  30  Imputed Spike in Vessel Propeller Shaft Mechanical Power               47597 non-null  int64
#  31  Imputed Spike in Vessel Propeller Shaft Rotational Speed               47597 non-null  int64
#  32  Imputed Spike in Vessel Propeller Shaft Torque                         47597 non-null  int64
#  33  Imputed Spike in Vessel Propeller Shaft Thrust Force                   47597 non-null  int64
#  34  Imputed Spike in Main Engine Fuel Load %                               47597 non-null  int64
#  35  Imputed Spike in Main Engine Scavenging Air Pressure                   47597 non-null  int64
#  36  n_obs                                                                  47597 non-null  int64
#  37  coverage                                                               47597 non-null  float64
#  38  Vessel External Conditions Northward Sea Water Velocity (Provider MB)  47597 non-null  float64
#  39  Vessel External Conditions Wave Significant Height (Provider MB)       47597 non-null  float64
#  40  Vessel External Conditions Eastward Wind Velocity (Provider S)         47597 non-null  float64
#  41  Vessel External Conditions Wind True Angle (Provider MB)               47597 non-null  float64
#  42  Vessel External Conditions Swell Significant Height (Provider MB)      47597 non-null  float64
#  43  Vessel External Conditions Sea Water Temperature (Provider S)          47597 non-null  float64
#  44  Vessel External Conditions Eastward Sea Water Velocity (Provider MB)   47597 non-null  float64
#  45  Vessel External Conditions Wave Period (Provider S)                    47597 non-null  float64
#  46  Vessel External Conditions Wind True Speed (Provider MB)               47597 non-null  float64
#  47  Vessel External Conditions Northward Sea Water Velocity (Provider S)   47597 non-null  float64
#  48  Vessel External Conditions Wave Significant Height (Provider S)        47597 non-null  float64
#  49  Vessel External Conditions Northward Wind Velocity (Provider S)        47597 non-null  float64
#  50  Fwd Draft (Noon Report)                                                47597 non-null  float64
#  51  Mid Draft (Noon Report)                                                47597 non-null  float64
#  52  Aft Draft (Noon Report)                                                47597 non-null  float64
#  53  Days Since Last Cleaning                                               47597 non-null  float64
#  54  Avg Draft (Calculated)                                                 47597 non-null  float64
#  55  Draft Trim (Calculated)                                                47597 non-null  float64
#  56  Speed Through Water^3 (m/s)                                            47597 non-null  float64
# dtypes: datetime64[us, UTC](1), float64(38), int64(18)
# memory usage: 20.7 MB

# %% [markdown]
# # 3. Predictive models
#
# This section defines a predictor set and benchmarks multiple machine learning models to predict shaft power.

# %% [markdown]
# ## 3.1. Ridge vs GAM vs Random Forest

# %% [markdown]
# ### 3.1.1. Setup

# %% [markdown]
# #### 3.1.1.1. Defining variables

# %%
TARGET_COLUMN = "Vessel Propeller Shaft Mechanical Power (KW)"

predictive_sensor_variables = [
    "Avg Draft (Calculated)",
    "Draft Trim (Calculated)",
    "Vessel Hull Through Water Longitudinal Speed (knots)",
    "Days Since Last Cleaning",
#    "Speed Through Water^3 (m/s)",
#    "Main Engine Fuel Load % (%)",
#   "Vessel Propeller Shaft Thrust Force (KN)",
#    "Vessel Propeller Shaft Rotational Speed (rpm)",
]

predictive_weather_variables = [
    "Vessel External Conditions Wind Relative Angle (degrees)",
    "Vessel External Conditions Wind Relative Speed (knots)",
    "Vessel External Conditions Sea Water Temperature (Provider S)",
#    "Vessel External Conditions Northward Sea Water Velocity (Provider MB)", # Make a current variable instead
#    "Vessel External Conditions Eastward Sea Water Velocity (Provider MB)", # Make a current variable instead 
    "Vessel External Conditions Wave Significant Height (Provider MB)",
#    "Vessel External Conditions Swell Significant Height (Provider MB)", # choose either swell or wave due to collinearity
#    "Vessel External Conditions Eastward Wind Velocity (Provider S)",
#    "Vessel External Conditions Wind True Angle (Provider MB)",
#    "Vessel External Conditions Wind True Speed (Provider MB)",
]

all_predictive_variables = predictive_sensor_variables + predictive_weather_variables

print(f"Target variable: {TARGET_COLUMN}")
print(f"Number of predictive variables: {len(all_predictive_variables)}")
print("Predictive variables:")
for variable in all_predictive_variables:
    print(f"- {variable}")
# Out:
# Target variable: Vessel Propeller Shaft Mechanical Power (KW)
# Number of predictive variables: 8
# Predictive variables:
# - Avg Draft (Calculated)
# - Draft Trim (Calculated)
# - Vessel Hull Through Water Longitudinal Speed (knots)
# - Days Since Last Cleaning
# - Vessel External Conditions Wind Relative Angle (degrees)
# - Vessel External Conditions Wind Relative Speed (knots)
# - Vessel External Conditions Sea Water Temperature (Provider S)
# - Vessel External Conditions Wave Significant Height (Provider MB)

# %% [markdown]
# #### 3.1.1.2. Loading data

# %%
model_df = (
    df[["window_start", TARGET_COLUMN] + all_predictive_variables]
    .sort_values("window_start")
    .dropna()
    .copy()
)

X = model_df[all_predictive_variables]
y = model_df[TARGET_COLUMN]

print(f"Rows available for modelling: {len(model_df):,}")
print(f"Feature matrix shape: {X.shape}")
# Out:
# Rows available for modelling: 47,597
# Feature matrix shape: (47597, 8)

# %%
if TIME_SPLIT:        
    split_index = int(len(model_df) * 0.8)

    X_train, X_test = X.iloc[:split_index], X.iloc[split_index:]
    y_train, y_test = y.iloc[:split_index], y.iloc[split_index:]
else:
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=random_seed)

# %% [markdown]
# #### 3.1.1.3. specifying model and pipeline components

# %%
# ---------------------------------------------------------
# 1. SETUP THE PHYSICS TRANSFORMATION
# ---------------------------------------------------------
SPEED_COL = "Vessel Hull Through Water Longitudinal Speed (knots)"

# Extract raw speed arrays for back-transformation later
speed_train = X_train[SPEED_COL].values
speed_test  = X_test[SPEED_COL].values

# Transform target to Power Coefficient: y / V^3
y_train_coeff = y_train.values / (speed_train ** 3)
y_test_coeff  = y_test.values / (speed_test ** 3)

# Remove speed from the feature matrices
X_train_no_speed = X_train.drop(columns=[SPEED_COL])
X_test_no_speed  = X_test.drop(columns=[SPEED_COL])

# %%
# ---------------------------------------------------------
# 2. BUILD THE PREPROCESSOR (Ignoring Speed)
# ---------------------------------------------------------
# Dynamically grab the remaining numeric features
# This scales the features and fills any missing sensor gaps with the median
numeric_pipeline = Pipeline(steps=[
    ('scaler', StandardScaler())
])

numeric_features_no_speed = X_train_no_speed.select_dtypes(include=['int64', 'float64']).columns.tolist()

preprocessor_no_speed = ColumnTransformer(
    transformers=[("numeric", numeric_pipeline, numeric_features_no_speed)],
    remainder="passthrough"
)

# %%
predictive_variables_no_speed = [var for var in all_predictive_variables if var != SPEED_COL]
gam_formula = None

for i, var_name in enumerate(predictive_variables_no_speed):
    if var_name == "Days Since Last Cleaning":
        term = s(i, constraints='monotonic_inc', n_splines=15)
    elif var_name == "Avg Draft (Calculated)":
        term = s(i, constraints='monotonic_inc', n_splines=10)
    elif var_name == "Vessel External Conditions Sea Water Temperature (Provider S)":
        term = s(i, constraints='monotonic_dec', n_splines=10)
    elif var_name == "Vessel External Conditions Wave Significant Height (Provider MB)":
        term = s(i, constraints='monotonic_inc', n_splines=10)
    elif var_name == "Vessel External Conditions Swell Significant Height (Provider MB)":
        term = s(i, constraints='monotonic_inc', n_splines=10)
    elif var_name == "Vessel External Conditions Wind Relative Angle (degrees)":
        term = s(i, basis='cp', n_splines=10, edge_knots=[0, 360])
    else:
        term = s(i, n_splines=10)
        
    if gam_formula is None:
        gam_formula = term
    else:
        gam_formula += term

# %%
# ---------------------------------------------------------
# 4. WRAPPER CLASS & PIPELINE
# ---------------------------------------------------------
class SklearnGAM(BaseEstimator, RegressorMixin):
    def __init__(self, formula):
        self.formula = formula
        
    def fit(self, X, y):
        self.gam_model_ = LinearGAM(self.formula)
        # Wider grid to ensure it can reach lambda=1e-6 for maximum unpenalized flexibility
        lam_grid = np.logspace(-6, 3, 20)
        self.gam_model_.gridsearch(X, y, lam=lam_grid)
        self.is_fitted_ = True 
        return self

    def predict(self, X):
        return self.gam_model_.predict(X)

# Create the final pipeline
gam_pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor_no_speed),
    ("model", SklearnGAM(formula=gam_formula))
])

# %%
# ---------------------------------------------------------
# 5. TRAIN, PREDICT, AND EVALUATE
# ---------------------------------------------------------
print("Training GAM Model...")
gam_pipeline.fit(X_train_no_speed, y_train_coeff)

# Predict the Coefficient
y_pred_train_coeff = gam_pipeline.predict(X_train_no_speed)
y_pred_test_coeff  = gam_pipeline.predict(X_test_no_speed)

# Back-transform to actual Shaft Power (kW)
y_pred_train_kw = y_pred_train_coeff * (speed_train ** 3)
y_pred_test_kw  = y_pred_test_coeff  * (speed_test ** 3)

# Print final metrics
print("\n--- Final Model Evaluation (in kW) ---")
print(f"Train RMSE: {root_mean_squared_error(y_train, y_pred_train_kw):.2f} kW")
print(f"Test RMSE:  {root_mean_squared_error(y_test, y_pred_test_kw):.2f} kW")
print(f"Train MAE:  {mean_absolute_error(y_train, y_pred_train_kw):.2f} kW")
print(f"Test MAE:   {mean_absolute_error(y_test, y_pred_test_kw):.2f} kW")
print(f"Test MAPE:  {mean_absolute_percentage_error(y_test, y_pred_test_kw)*100:.2f}%")
# Out:
#   0% (0 of 20) |                         | Elapsed Time: 0:00:00 ETA:  --:--:--
# Training GAM Model...
#   5% (1 of 20) |#                        | Elapsed Time: 0:00:14 ETA:   0:04:41
#  10% (2 of 20) |##                       | Elapsed Time: 0:00:19 ETA:   0:02:57
#  15% (3 of 20) |###                      | Elapsed Time: 0:00:22 ETA:   0:02:09
#  20% (4 of 20) |#####                    | Elapsed Time: 0:00:27 ETA:   0:01:49
#  25% (5 of 20) |######                   | Elapsed Time: 0:00:31 ETA:   0:01:34
#  30% (6 of 20) |#######                  | Elapsed Time: 0:00:35 ETA:   0:01:23
#  35% (7 of 20) |########                 | Elapsed Time: 0:00:39 ETA:   0:01:13
#  40% (8 of 20) |##########               | Elapsed Time: 0:00:44 ETA:   0:01:06
#  45% (9 of 20) |###########              | Elapsed Time: 0:00:49 ETA:   0:01:00
#  50% (10 of 20) |############            | Elapsed Time: 0:00:53 ETA:   0:00:53
#  55% (11 of 20) |#############           | Elapsed Time: 0:00:59 ETA:   0:00:48
#  60% (12 of 20) |##############          | Elapsed Time: 0:01:06 ETA:   0:00:44
#  65% (13 of 20) |###############         | Elapsed Time: 0:01:11 ETA:   0:00:38
#  70% (14 of 20) |################        | Elapsed Time: 0:01:15 ETA:   0:00:32
#  75% (15 of 20) |##################      | Elapsed Time: 0:01:18 ETA:   0:00:26
#  80% (16 of 20) |###################     | Elapsed Time: 0:01:22 ETA:   0:00:20
#  85% (17 of 20) |####################    | Elapsed Time: 0:01:25 ETA:   0:00:15
#  90% (18 of 20) |#####################   | Elapsed Time: 0:01:29 ETA:   0:00:09
#  95% (19 of 20) |######################  | Elapsed Time: 0:01:36 ETA:   0:00:05
# 100% (20 of 20) |########################| Elapsed Time: 0:01:45 Time:  0:01:45
# --- Final Model Evaluation (in kW) ---
# Train RMSE: 707.76 kW
# Test RMSE:  683.18 kW
# Train MAE:  472.22 kW
# Test MAE:   463.72 kW
# Test MAPE:  11.40%

# %% [markdown]
# ### 3.1.2. Running pipeline

# %% [markdown]
# ### 3.1.3. Quick residual diagnostics

# %%
y_pred_test = y_pred_test_kw

rmse = root_mean_squared_error(y_test, y_pred_test)  # true RMSE [web:156]

histogram = sns.histplot(y_test - y_pred_test, bins=30, kde=True)
histogram.set_title("Residuals Distribution")
histogram.set_xlabel("Residuals")
histogram.set_ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# make scatterplot of the residuals vs the actual values, as well as each of the features (to see what what kind of values it is struggling to predict)
for feature in all_predictive_variables:
    scatter = sns.scatterplot(x=X_test[feature], y=y_test - y_pred_test)
    scatter.set_title(f"Residuals vs {feature}")
    scatter.set_xlabel(feature)
    scatter.set_ylabel("Residuals")
    plt.show()

# %% [markdown]
# ## 3.2. Synthetic test scenario

# %% [markdown]
# ### 3.2.1. Setting values

# %%
speed_values = [8, 8.5, 9, 9.5,10, 10.5, 11, 11.5, 12, 12.5, 13, 13.5, 14] # for varying speed
dsc_range = range(0, 151, 1) # for varying fouling from 0 to 150 days since cleaning

# split the list of predictive variables into draft and non draft by looking for the word "draft" in the variable name
speed_variable = "Vessel Hull Through Water Longitudinal Speed (knots)"
dsc_variable = "Days Since Last Cleaning"
draft_variables = [feature for feature in all_predictive_variables if "Draft" in feature]
non_draft_variables = [feature for feature in all_predictive_variables if "Draft" not in feature and feature != speed_variable and feature != dsc_variable]
draft_and_non_draft_variables = draft_variables + non_draft_variables

logger.info(f'speed variable: {speed_variable}')
logger.info(f'dsc variable: {dsc_variable}')
logger.info(f"Draft variables: {draft_variables}")
logger.info(f"Non-draft variables: {non_draft_variables}")

# intialize a dictionary and set the keys to be the selected predictive variable names execpt for dsc
typical_values = {feature: [] for feature in all_predictive_variables}

# drop the speed and cleaning date variables from the typical values dict
typical_values.pop(dsc_variable, None)
typical_values.pop(speed_variable, None)

# for the values in the dictionary, take the mean value of each feature in the training set ofr the non-draft variables, and for the draft variables, set them to be the median
for feature in all_predictive_variables:
    if feature in non_draft_variables:
        typical_values[feature] = X_train[feature].mean()
    elif feature in draft_variables:
        # set draft variables to be the median instead
        typical_values[feature] = X_train[feature].median()

typical_values
# Out:
# 2026-02-24 16:28:34.518 | INFO     | __main__:<module>:11 - speed variable: Vessel Hull Through Water Longitudinal Speed (knots)
# 2026-02-24 16:28:34.519 | INFO     | __main__:<module>:12 - dsc variable: Days Since Last Cleaning
# 2026-02-24 16:28:34.520 | INFO     | __main__:<module>:13 - Draft variables: ['Avg Draft (Calculated)', 'Draft Trim (Calculated)']
# 2026-02-24 16:28:34.521 | INFO     | __main__:<module>:14 - Non-draft variables: ['Vessel External Conditions Wind Relative Angle (degrees)', 'Vessel External Conditions Wind Relative Speed (knots)', 'Vessel External Conditions Sea Water Temperature (Provider S)', 'Vessel External Conditions Wave Significant Height (Provider MB)']
# {'Avg Draft (Calculated)': np.float64(9.945),
#  'Draft Trim (Calculated)': np.float64(1.0),
#  'Vessel External Conditions Wind Relative Angle (degrees)': np.float64(205.2431728161802),
#  'Vessel External Conditions Wind Relative Speed (knots)': np.float64(21.467125335156222),
#  'Vessel External Conditions Sea Water Temperature (Provider S)': np.float64(24.299006186380847),
#  'Vessel External Conditions Wave Significant Height (Provider MB)': np.float64(2.0123813819983964)}

# %% [markdown]
# ### 3.2.2. Build synhtetic test set

# %%
# build a dataframe with a column for each of the "all predictive variables", and a row for each combination of speed and days since cleaning, where the values in the dataframe are the typical values for each variable, except for speed and days since cleaning which take the values from the lists defined above
simulation_df = pd.DataFrame(columns=all_predictive_variables)
for speed in speed_values:
    for dsc in dsc_range:
        row = {feature: typical_values[feature] for feature in draft_and_non_draft_variables}
        row[speed_variable] = speed
        row[dsc_variable] = dsc
        simulation_df = pd.concat([simulation_df, pd.DataFrame([row])], ignore_index=True)


logger.info(f"Simulation dataframe shape: {simulation_df.shape}")
# Out:
# 2026-02-24 16:28:39.650 | INFO     | __main__:<module>:11 - Simulation dataframe shape: (1963, 8)

# %% [markdown]
# #### 3.2.2.1 add predictions

# %%
chosen_pipeline = gam_pipeline
model_name = "Physics-Constrained GAM"

print(f"Active Model: {model_name}")
# Out:
# Active Model: Physics-Constrained GAM

# %%
# scale the simulation features based on the scaler from the best pipeline
simulation_df['Predicted Shaft Power'] = chosen_pipeline.predict(simulation_df)

simulation_df
# Out:
#      Avg Draft (Calculated) Draft Trim (Calculated)  \
# 0                     9.945                     1.0
# 1                     9.945                     1.0
# 2                     9.945                     1.0
# 3                     9.945                     1.0
# 4                     9.945                     1.0
# ...                     ...                     ...
# 1958                  9.945                     1.0
# 1959                  9.945                     1.0
# 1960                  9.945                     1.0
# 1961                  9.945                     1.0
# 1962                  9.945                     1.0
#
#      Vessel Hull Through Water Longitudinal Speed (knots)  \
# 0                                                     8
# 1                                                     8
# 2                                                     8
# 3                                                     8
# 4                                                     8
# ...                                                 ...
# 1958                                                 14
# 1959                                                 14
# 1960                                                 14
# 1961                                                 14
# 1962                                                 14
#
#      Days Since Last Cleaning  \
# 0                           0
# 1                           1
# 2                           2
# 3                           3
# 4                           4
# ...                       ...
# 1958                      146
# 1959                      147
# 1960                      148
# 1961                      149
# 1962                      150
#
#      Vessel External Conditions Wind Relative Angle (degrees)  \
# 0                                            205.243173
# 1                                            205.243173
# 2                                            205.243173
# 3                                            205.243173
# 4                                            205.243173
# ...                                                 ...
# 1958                                         205.243173
# 1959                                         205.243173
# 1960                                         205.243173
# 1961                                         205.243173
# 1962                                         205.243173
#
#      Vessel External Conditions Wind Relative Speed (knots)  \
# 0                                             21.467125
# 1                                             21.467125
# 2                                             21.467125
# 3                                             21.467125
# 4                                             21.467125
# ...                                                 ...
# 1958                                          21.467125
# 1959                                          21.467125
# 1960                                          21.467125
# 1961                                          21.467125
# 1962                                          21.467125
#
#      Vessel External Conditions Sea Water Temperature (Provider S)  \
# 0                                             24.299006
# 1                                             24.299006
# 2                                             24.299006
# 3                                             24.299006
# 4                                             24.299006
# ...                                                 ...
# 1958                                          24.299006
# 1959                                          24.299006
# 1960                                          24.299006
# 1961                                          24.299006
# 1962                                          24.299006
#
#      Vessel External Conditions Wave Significant Height (Provider MB)  \
# 0                                              2.012381
# 1                                              2.012381
# 2                                              2.012381
# 3                                              2.012381
# 4                                              2.012381
# ...                                                 ...
# 1958                                           2.012381
# 1959                                           2.012381
# 1960                                           2.012381
# 1961                                           2.012381
# 1962                                           2.012381
#
#       Predicted Shaft Power
# 0                  1.910755
# 1                  1.910755
# 2                  1.910755
# 3                  1.910755
# 4                  1.910755
# ...                     ...
# 1958               1.958133
# 1959               1.958133
# 1960               1.958133
# 1961               1.958133
# 1962               1.958133
#
# [1963 rows x 9 columns]

# %%
# for each value of speed in the synthetic dataframe, print the number of unique values and descriptive statistics for the predicted shaft power
for speed in speed_values:
    speed_df = simulation_df[simulation_df[speed_variable] == speed]
    logger.info(f"Speed: {speed} knots")
    logger.info(f"Number of unique predicted shaft power values: {speed_df['Predicted Shaft Power'].nunique()}")
    logger.info(f"Descriptive statistics for predicted shaft power:\n{speed_df['Predicted Shaft Power'].describe()}")
# Out:
# 2026-02-24 16:30:31.497 | INFO     | __main__:<module>:4 - Speed: 8 knots
# 2026-02-24 16:30:31.499 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.503 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.505 | INFO     | __main__:<module>:4 - Speed: 8.5 knots
# 2026-02-24 16:30:31.506 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.509 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.511 | INFO     | __main__:<module>:4 - Speed: 9 knots
# 2026-02-24 16:30:31.512 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.515 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.517 | INFO     | __main__:<module>:4 - Speed: 9.5 knots
# 2026-02-24 16:30:31.518 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.522 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.524 | INFO     | __main__:<module>:4 - Speed: 10 knots
# 2026-02-24 16:30:31.525 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.529 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.531 | INFO     | __main__:<module>:4 - Speed: 10.5 knots
# 2026-02-24 16:30:31.532 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.535 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.536 | INFO     | __main__:<module>:4 - Speed: 11 knots
# 2026-02-24 16:30:31.537 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.540 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.541 | INFO     | __main__:<module>:4 - Speed: 11.5 knots
# 2026-02-24 16:30:31.541 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.544 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.545 | INFO     | __main__:<module>:4 - Speed: 12 knots
# 2026-02-24 16:30:31.545 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.548 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.549 | INFO     | __main__:<module>:4 - Speed: 12.5 knots
# 2026-02-24 16:30:31.550 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.552 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.553 | INFO     | __main__:<module>:4 - Speed: 13 knots
# 2026-02-24 16:30:31.553 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.556 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.558 | INFO     | __main__:<module>:4 - Speed: 13.5 knots
# 2026-02-24 16:30:31.559 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.563 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64
# 2026-02-24 16:30:31.564 | INFO     | __main__:<module>:4 - Speed: 14 knots
# 2026-02-24 16:30:31.565 | INFO     | __main__:<module>:5 - Number of unique predicted shaft power values: 151
# 2026-02-24 16:30:31.568 | INFO     | __main__:<module>:6 - Descriptive statistics for predicted shaft power:
# count    151.000000
# mean       1.942144
# std        0.021079
# min        1.910754
# 25%        1.912431
# 50%        1.958133
# 75%        1.958134
# max        1.958136
# Name: Predicted Shaft Power, dtype: float64

# %% [markdown]
# ### 3.2.3. Analyse

# %%
def plot_speed_power_by_dsc(df, dsc_values):
    """
    Plots Speed vs Predicted Power for specific Days Since Last Cleaning (DSC) values.

    Parameters:
    - df: pandas DataFrame containing the synthetic test set.
    - dsc_values: list of integers representing the specific DSC days to plot (e.g., [0, 50, 100]).
    """
    
    # Define column names based on your dataframe
    col_speed = 'Vessel Hull Through Water Longitudinal Speed (knots)'
    col_power = 'Predicted Shaft Power'
    col_dsc = 'Days Since Last Cleaning'
    
    # 1. Filter the dataframe to only include the requested DSC values
    plot_data = df[df[col_dsc].isin(dsc_values)].copy()
    
    # Check if data exists after filtering
    if plot_data.empty:
        print("Warning: No data found for the provided DSC values.")
        return

    # 2. Setup the plot
    plt.figure(figsize=(10, 6))
    sns.set_style("whitegrid")
    
    # 3. Create the scatterplot
    # We convert 'col_dsc' to categorical types/strings temporarily for the hue 
    # to ensure distinct colors (discrete palette) instead of a gradient.
    sns.scatterplot(
        data=plot_data,
        x=col_speed, 
        y=col_power, 
        hue=col_dsc,
        palette="viridis",  # Color map
        s=100,              # Dot size
        edgecolor='black',  # Add border to dots for clarity
        alpha=0.8           # Slight transparency
    )
    
    # 4. Formatting
    plt.title('Speed vs Predicted Power at Different Fouling Levels', fontsize=14)
    plt.xlabel('Speed (knots)', fontsize=12)
    plt.ylabel('Predicted Shaft Power', fontsize=12)
    plt.legend(title='Days Since Last Cleaning', bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout()
    plt.show()

# %%
plot_speed_power_by_dsc(simulation_df, dsc_values=[30, 150])

# %%
fouling_idx = all_predictive_variables.index("Days Since Last Cleaning")
print(f"Fouling is at index: {fouling_idx}")
# Out:
# Fouling is at index: 3

# %% [markdown]
# ## 3.3. GAM model

# %% [markdown]
# ### 3.3.1. Model summary & diagnostics

# %% [markdown]
# Checks already confirmed:
#
# Concurvity: Neutralized by monotonic constraints
#
# Speed-Power Curve: Visually confirmed to follow a $V^3$ curve
#
# Fouling Curve: Confirmed to follow a biological S-curve shape
#
# Overfitting: Confirmed resolved (Train RMSE ≈ Test RMSE)
#
# EDoF vs. Lambda: Confirmed model is using appropriate flexibility
#
# Physical constraints: Confirmed monotonic on Speed, DSC, Draft, Wave Height

# %% [markdown]
# #### 3.3.1.1. Summary
#
# The EDoF should not be too close to n_splines (then n_splines should be increased)

# %%
# 1. Find the NEW index of the Fouling variable (since Speed was removed)
fouling_idx = predictive_variables_no_speed.index("Days Since Last Cleaning")

# 2. Extract the raw pyGAM model directly from our new standalone pipeline
actual_pygam_model = gam_pipeline.named_steps["model"].gam_model_

# 3. Generate a perfectly spaced grid of 100 points for the fouling feature
XX = actual_pygam_model.generate_X_grid(term=fouling_idx)

# 4. Extract the partial dependence and 95% CI
# IMPORTANT: Because our target was (Power / V^3), these are COEFFICIENTS, not kW!
pdep_coeff, confi_coeff = actual_pygam_model.partial_dependence(term=fouling_idx, X=XX, width=0.95)

# 5. TRANSLATE TO kW: Multiply the coefficient by a standard cruising speed cubed
cruising_speed = 13.0  # Typical bulk carrier cruising speed
speed_multiplier = cruising_speed ** 3

pdep = pdep_coeff * speed_multiplier
confi = confi_coeff * speed_multiplier

# 6. We only want to plot the X-axis for the fouling variable itself
x_axis_values = XX[:, fouling_idx]

# %%
all_predictive_variables
# Out:
# ['Avg Draft (Calculated)',
#  'Draft Trim (Calculated)',
#  'Vessel Hull Through Water Longitudinal Speed (knots)',
#  'Days Since Last Cleaning',
#  'Vessel External Conditions Wind Relative Angle (degrees)',
#  'Vessel External Conditions Wind Relative Speed (knots)',
#  'Vessel External Conditions Sea Water Temperature (Provider S)',
#  'Vessel External Conditions Wave Significant Height (Provider MB)']

# %%
actual_pygam_model.summary()
# Out:
# LinearGAM
# =============================================== ==========================================================
# Distribution:                        NormalDist Effective DoF:                                      28.105
# Link Function:                     IdentityLink Log Likelihood:                                -34968.3051
# Number of Samples:                        38077 AIC:                                            69994.8201
#                                                 AICc:                                           69994.8662
#                                                 GCV:                                                0.3682
#                                                 Scale:                                              0.6064
#                                                 Pseudo R-Squared:                                   0.5791
# ==========================================================================================================
# Feature Function                  Lambda               Rank         EDoF         P > x        Sig. Code
# ================================= ==================== ============ ============ ============ ============
# s(0)                              [0.]                 10           7.1          1.11e-16     ***
# s(1)                              [0.]                 10           3.4          1.11e-16     ***
# s(2)                              [0.]                 15           2.1          1.11e-16     ***
# s(3)                              [0.]                 10           1.9          1.11e-16     ***
# s(4)                              [0.]                 10           8.4          1.11e-16     ***
# s(5)                              [0.]                 10           1.0          1.11e-16     ***
# s(6)                              [0.]                 10           4.1          1.11e-16     ***
# intercept                                              1            0.0          3.82e-08     ***
# ==========================================================================================================
# Significance codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# WARNING: Fitting splines and a linear function to a feature introduces a model identifiability problem
#          which can cause p-values to appear significant when they are not.
#
# WARNING: p-values calculated in this manner behave correctly for un-penalized models or models with
#          known smoothing parameters, but when smoothing parameters have been estimated, the p-values
#          are typically lower than they should be, meaning that the tests reject the null too readily.
# /tmp/ipykernel_18795/4038382217.py:1: UserWarning: KNOWN BUG: p-values computed in this summary are likely much smaller than they should be.
#
# Please do not make inferences based on these values!
#
# Collaborate on a solution, and stay up to date at:
# github.com/dswah/pyGAM/issues/163
#
#   actual_pygam_model.summary()

# %% [markdown]
# #### 3.3.1.2. Concurvity check

# %%
# Assuming your dataframe is 'df' and these are your features
target_feature = 'Days Since Last Cleaning'
other_features = all_predictive_variables.copy() # Add your other continuous variables here
other_features.remove(target_feature)  # Remove the target feature from the list of other features

# 1. Isolate the target feature (y) and the others (X)
y_concurvity = X_train[target_feature]
X_concurvity = X_train[other_features]

# 2. Fit a GAM predicting Days Since Cleaning based on the other features
# We use s(0) + s(1) to apply splines to both Speed and Draft
concurvity_model = LinearGAM(s(0) + s(1)).fit(X_concurvity, y_concurvity)

# 3. Extract the R-squared (Explained Deviance)
# 0.0 means no concurvity. 1.0 means complete overlap (bad).
concurvity_index = concurvity_model.statistics_['pseudo_r2']['explained_deviance']

print(f"Concurvity Index for {target_feature}: {concurvity_index:.4f}")
if concurvity_index > 0.7:
    print("WARNING: Severe concurvity detected. The model cannot separate the effect of fouling from the other variables.")
# Out:
# Concurvity Index for Days Since Last Cleaning: 0.9725
# WARNING: Severe concurvity detected. The model cannot separate the effect of fouling from the other variables.

# %% [markdown]
# #### 3.3.1.3. residuals v predicted values

# %%
SPEED_COL = "Vessel Hull Through Water Longitudinal Speed (knots)"

# 1) Use the same feature set the model was trained on (no speed)
X_test_no_speed = X_test.drop(columns=[SPEED_COL])
X_train_no_speed = X_train.drop(columns=[SPEED_COL])

# 2) Predict on coefficient scale
pred_test_coeff  = gam_pipeline.predict(X_test_no_speed)
pred_train_coeff = gam_pipeline.predict(X_train_no_speed)

# 3) Back-transform to kW using the *raw* speeds
speed_test = X_test[SPEED_COL].to_numpy()
speed_train = X_train[SPEED_COL].to_numpy()

gam_pred_test_kw  = pred_test_coeff  * (speed_test ** 3)
gam_pred_train_kw = pred_train_coeff * (speed_train ** 3)

# 4) Residuals in kW
gam_residuals_test = np.asarray(y_test) - gam_pred_test_kw

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Actual vs Predicted (kW vs kW)
axes[0].scatter(gam_pred_test_kw, y_test, alpha=0.15, s=8, edgecolors='none')
lims = [
    min(gam_pred_test_kw.min(), np.min(y_test)),
    max(gam_pred_test_kw.max(), np.max(y_test)),
]
axes[0].plot(lims, lims, 'r--', linewidth=1, label='Perfect prediction')
axes[0].set_xlabel("Predicted Shaft Power (kW)", fontsize=12)
axes[0].set_ylabel("Actual Shaft Power (kW)", fontsize=12)
axes[0].set_title("Actual vs Predicted (GAM)", fontsize=14)
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# Residuals vs Predicted
axes[1].scatter(gam_pred_test_kw, gam_residuals_test, alpha=0.15, s=8, edgecolors='none')
axes[1].axhline(y=0, color='red', linestyle='--', linewidth=1)
axes[1].set_xlabel("Predicted Shaft Power (kW)", fontsize=12)
axes[1].set_ylabel("Residual (actual − predicted) (kW)", fontsize=12)
axes[1].set_title("Residuals vs Predicted (GAM)", fontsize=14)
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.3.1.4. QQ plot / normality of residuals

# %%
from scipy import stats

# Ensure residuals are 1D finite numbers (kW scale)
resid = np.asarray(gam_residuals_test).ravel()
resid = resid[np.isfinite(resid)]

# --- QQ Plot ---
fig, ax = plt.subplots(figsize=(7, 7))
stats.probplot(resid, dist="norm", plot=ax)  # default is normal probability plot [web:440]
ax.set_title("QQ Plot of GAM Residuals (kW)", fontsize=14)
ax.get_lines()[0].set(markersize=3, alpha=0.4)
ax.get_lines()[1].set(color='red', linewidth=1.5)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# --- Shapiro-Wilk on subsample (<= 5000) ---
random_seed = 42
rng = np.random.default_rng(random_seed)

sample = resid if resid.size <= 5000 else rng.choice(resid, 5000, replace=False)
stat, p_value = stats.shapiro(sample)  # p-value may not be accurate for N>5000 [page:1]
print(f"Shapiro-Wilk → statistic = {stat:.6f}, p-value = {p_value:.4e}")
# Out:
# Shapiro-Wilk → statistic = 0.890197, p-value = 8.5049e-51

# %% [markdown]
# #### 3.3.1.5. residuals over time

# %%
# --- Residuals over time ---
test_times = model_df.loc[X_test.index, "window_start"]

fig, ax = plt.subplots(figsize=(16, 5))
ax.scatter(test_times, gam_residuals_test, alpha=0.15, s=5, edgecolors='none')
ax.axhline(y=0, color='red', linestyle='--', linewidth=1)

# Rolling mean of residuals to highlight drift
rolling_df = pd.DataFrame({"time": test_times.values, "residual": gam_residuals_test}).sort_values("time")
window = max(len(rolling_df) // 50, 10)
rolling_mean = rolling_df["residual"].rolling(window=window, center=True).mean()
ax.plot(rolling_df["time"], rolling_mean, color='darkorange', linewidth=2, label=f'Rolling mean (w={window})')

ax.set_title("GAM Residuals Over Time", fontsize=14)
ax.set_xlabel("Time", fontsize=12)
ax.set_ylabel("Residual (actual − predicted)", fontsize=12)
ax.legend()
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.3.1.6. Residuals vs days since cleaning

# %%
def plot_residual_boxplots(
    X_test,
    y_test,
    y_pred,
    variable_name,
    n_buckets=5,
    value_limits=None,
):
    """
    Creates a violin plot of residuals bucketed by a comparison variable.

    Parameters
    ----------
    X_test : pd.DataFrame
        Test feature matrix.
    y_test : pd.Series or np.ndarray
        True target values.
    y_pred : np.ndarray
        Predicted target values.
    variable_name : str
        Column name in X_test to bucket by.
    n_buckets : int, optional
        Number of equal-frequency (quantile) buckets (default 5).
    value_limits : tuple of (min, max), optional
        If provided, clips the comparison variable to [min, max] before
        bucketing, and drops rows outside this range.
    """
    residuals = np.asarray(y_test) - np.asarray(y_pred)
    plot_df = pd.DataFrame({
        "variable": X_test[variable_name].values,
        "residual": residuals,
    })

    # optional filtering by value limits
    if value_limits is not None:
        lo, hi = value_limits
        plot_df = plot_df[(plot_df["variable"] >= lo) & (plot_df["variable"] <= hi)]

    # create buckets using quantile-based binning
    plot_df["bucket"] = pd.cut(
        plot_df["variable"],
        bins=n_buckets,
        duplicates="drop",
    )

    # sort by bucket for a clean axis order
    plot_df = plot_df.sort_values("bucket")

    # plot
    fig, ax = plt.subplots(figsize=(12, 6))
    sns.violinplot(
        data=plot_df,
        x="bucket",
        y="residual",
        ax=ax,
        inner="box",
        cut=0,
    )
    ax.axhline(y=0, color="red", linestyle="--", linewidth=1)
    ax.set_title(f"Residuals by {variable_name}", fontsize=14)
    ax.set_xlabel(variable_name, fontsize=12)
    ax.set_ylabel("Residual (actual − predicted)", fontsize=12)
    plt.xticks(rotation=30, ha="right")
    plt.tight_layout()
    plt.show()

# --- Residuals vs Days Since Last Cleaning ---
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Left: scatter
axes[0].scatter(X_test["Days Since Last Cleaning"], gam_residuals_test, alpha=0.15, s=5, edgecolors='none')
axes[0].axhline(y=0, color='red', linestyle='--', linewidth=1)
axes[0].set_xlabel("Days Since Last Cleaning", fontsize=12)
axes[0].set_ylabel("Residual (actual − predicted)", fontsize=12)
axes[0].set_title("GAM Residuals vs Days Since Cleaning", fontsize=14)
axes[0].grid(True, alpha=0.3)

# Right: violin plot bucketed by DSC
plot_residual_boxplots(
    X_test=X_test,
    y_test=y_test,
    y_pred=y_pred_test,
    variable_name="Days Since Last Cleaning",
    n_buckets=8,
)

# %% [markdown]
# #### 3.3.1.7. Sea trial curves validation

# %%
CLEANING_DATES = [
    pd.Timestamp("2024-01-04", tz="UTC"),
    pd.Timestamp("2024-07-10", tz="UTC"),
]
CLEAN_HULL_DAYS = 7  # only keep the first N days after each cleaning

# 1. Identify rows within `CLEAN_HULL_DAYS` of any cleaning event
clean_hull_mask = model_df["Days Since Last Cleaning"] <= CLEAN_HULL_DAYS
clean_df = model_df[clean_hull_mask].copy()

# 2. Build a synthetic "sea trial" dataframe
# We hold all non-speed features at their median, and DSC = 0
speed_variable = "Vessel Hull Through Water Longitudinal Speed (knots)"
dsc_variable = "Days Since Last Cleaning"

# Get the list of features the pipeline actually expects (everything EXCEPT speed)
expected_features = [f for f in X_train.columns if f != speed_variable]

# Create a range of speeds to plot
speed_range = np.linspace(
    X_train[speed_variable].min(),
    X_train[speed_variable].max(),
    200,
)

# Build the synthetic dataframe (only expected features)
sea_trial_rows = []
for _ in range(len(speed_range)):
    row = {feat: X_train[feat].median() for feat in expected_features}
    row[dsc_variable] = 0  # perfectly clean hull
    sea_trial_rows.append(row)

sea_trial_df = pd.DataFrame(sea_trial_rows)

# 3. Predict the COEFFICIENT on the synthetic data, then transform to kW using the speed range
pred_coeff_synthetic = gam_pipeline.predict(sea_trial_df)
sea_trial_power_kw = pred_coeff_synthetic * (speed_range ** 3)

# 4. Plot
fig, ax = plt.subplots(figsize=(12, 7))

# Scatter: actual observations from the clean-hull period
ax.scatter(
    clean_df[speed_variable],
    clean_df[TARGET_COLUMN],
    alpha=0.10, s=8, edgecolors="none", color="grey",
    label=f"Actual (first {CLEAN_HULL_DAYS} d after cleaning)",
)

# Line: GAM prediction at DSC = 0 (synthetic sea-trial curve)
ax.plot(
    speed_range,
    sea_trial_power_kw,
    color="darkblue", linewidth=2.5,
    label="GAM prediction (DSC = 0, median conditions)",
)

ax.set_title("Sea-Trial Validation: GAM Speed-Power Curve vs. Clean-Hull Observations", fontsize=14)
ax.set_xlabel("Speed Through Water (knots)", fontsize=12)
ax.set_ylabel("Shaft Power (kW)", fontsize=12)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### 3.3.1.8. Cleaning event reset check

# %%
CLEANING_DATES = [
    pd.Timestamp("2024-01-04", tz="UTC"),
    pd.Timestamp("2024-07-10", tz="UTC"),
]

time_col  = "window_start"
speed_col = "Vessel Hull Through Water Longitudinal Speed (knots)"
dsc_col   = "Days Since Last Cleaning"

# 1) Predict coefficient on full dataset using the features the pipeline expects (no speed)
X_full_no_speed = model_df.drop(columns=[speed_col])
pred_coeff_full = gam_pipeline.predict(X_full_no_speed)

# 2) Back-transform to kW using the actual speed per row
speed_full = model_df[speed_col].to_numpy()
pred_kw_full = pred_coeff_full * (speed_full ** 3)

# 3) Residuals in kW + tidy frame (keep DSC inside same frame to avoid misalignment)
res_df = (
    pd.DataFrame({
        "time": model_df[time_col].to_numpy(),
        "residual": model_df[TARGET_COLUMN].to_numpy() - pred_kw_full,
        "dsc": model_df[dsc_col].to_numpy(),
    })
    .sort_values("time")
    .reset_index(drop=True)
)

roll_w = max(len(res_df) // 80, 20)
res_df["rolling_mean"] = res_df["residual"].rolling(window=roll_w, center=True).mean()

# 4) Plot
fig, axes = plt.subplots(
    2, 1, figsize=(18, 10), sharex=True,
    gridspec_kw={"height_ratios": [3, 1]}
)

ax = axes[0]
ax.scatter(res_df["time"], res_df["residual"], alpha=0.08, s=4,
           edgecolors="none", color="steelblue")
ax.plot(res_df["time"], res_df["rolling_mean"], color="darkorange",
        linewidth=2, label=f"Rolling mean (w={roll_w})")
ax.axhline(y=0, color="red", linestyle="--", linewidth=1)

for cd in CLEANING_DATES:
    ax.axvline(x=cd, color="green", linestyle="-", linewidth=2, alpha=0.8)

ax.set_ylabel("Residual (actual − predicted) [kW]", fontsize=12)
ax.set_title("GAM Residuals Over Time with Cleaning Events", fontsize=14)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)

ax2 = axes[1]
ax2.plot(res_df["time"], res_df["dsc"], color="purple", linewidth=1, alpha=0.6)
for cd in CLEANING_DATES:
    ax2.axvline(x=cd, color="green", linestyle="-", linewidth=2, alpha=0.8)

ax2.set_ylabel("Days Since\nLast Cleaning", fontsize=11)
ax2.set_xlabel("Time", fontsize=12)
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# 5) Quantitative check: early vs late (now aligned because it's inside res_df)
early = res_df.loc[res_df["dsc"] <= 7, "residual"]
late  = res_df.loc[res_df["dsc"] >= 90, "residual"]

logger.info(f"Mean residual  0-7 days after cleaning : {early.mean():+.1f} kW  (n={len(early):,})")
logger.info(f"Mean residual 90+ days after cleaning : {late.mean():+.1f} kW  (n={len(late):,})")
logger.info(f"Difference (late − early)             : {late.mean() - early.mean():+.1f} kW")
# Out:
# 2026-02-24 16:37:10.773 | INFO     | __main__:<module>:69 - Mean residual  0-7 days after cleaning : +395.5 kW  (n=856)
# 2026-02-24 16:37:10.774 | INFO     | __main__:<module>:70 - Mean residual 90+ days after cleaning : -132.2 kW  (n=21,574)
# 2026-02-24 16:37:10.775 | INFO     | __main__:<module>:71 - Difference (late − early)             : -527.7 kW

# %% [markdown]
# ### 3.3.2. Fouling / speed curve

# %% [markdown]
# #### 3.3.2.1. Fouling penalty by day since clean

# %%
scaler = gam_pipeline.named_steps["preprocessor"].named_transformers_["numeric"].named_steps["scaler"]

# 2. Unscale the grid points so the X-axis is back in real "Days"
XX_unscaled = scaler.inverse_transform(XX)
real_days = XX_unscaled[:, fouling_idx]

# 3. Filter to only include days up to 160
mask = real_days <= 160
real_days_filtered = real_days[mask]
pdep_filtered = pdep[mask]
confi_filtered = confi[mask]


# Shift the curve to start at 0 for readability
# pyGAM's generate_X_grid creates a sorted array, so the 0th index is the minimum day
baseline_power = pdep_filtered[0]

# Subtract the baseline value from both the main prediction and the CI bounds
pdep_shifted = pdep_filtered - baseline_power
confi_shifted = confi_filtered - baseline_power

# 4. Plot the final, isolated Fouling Curve
plt.figure(figsize=(10, 6))

# Plot the main partial dependence line (using SHIFTED values)
plt.plot(real_days_filtered, pdep_shifted, color='darkblue', linewidth=2.5, label='Added Fouling Penalty')

# Plot the 95% Confidence Interval bounds (using SHIFTED values)
plt.fill_between(real_days_filtered, confi_shifted[:, 0], confi_shifted[:, 1], color='cornflowerblue', alpha=0.3, label='95% Confidence Interval')

# Formatting
plt.title("Isolated Impact of Hull Fouling on Shaft Power (Clean Hull Baseline)", fontsize=14)
plt.xlabel("Days Since Last Cleaning", fontsize=12)
plt.ylabel("Added Shaft Power (kW)", fontsize=12) # Updated label to be more intuitive
plt.axhline(y=0, color='red', linestyle='--', linewidth=1) # Baseline
plt.xlim(0, 160)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# find average shaft power in the test set
average_test_power = y_test.mean()

# find the maximum value in the plot above
max_fouling_penalty = pdep_shifted.max()
max_fouling_penalty_percentage = (max_fouling_penalty / average_test_power) * 100

print(f'max fouling penalty (kW): {max_fouling_penalty:.2f} kW')
print(f'max fouling penalty percentage: {max_fouling_penalty_percentage:.2f} %')
# Out:
# max fouling penalty (kW): 104.10 kW
# max fouling penalty percentage: 2.43 %

# %% [markdown]
# ### 3.3.2.1 Fouling penalty by speed

# %%
simulation_df
# Out:
#      Avg Draft (Calculated) Draft Trim (Calculated)  \
# 0                     9.945                     1.0
# 1                     9.945                     1.0
# 2                     9.945                     1.0
# 3                     9.945                     1.0
# 4                     9.945                     1.0
# ...                     ...                     ...
# 1958                  9.945                     1.0
# 1959                  9.945                     1.0
# 1960                  9.945                     1.0
# 1961                  9.945                     1.0
# 1962                  9.945                     1.0
#
#      Vessel Hull Through Water Longitudinal Speed (knots)  \
# 0                                                     8
# 1                                                     8
# 2                                                     8
# 3                                                     8
# 4                                                     8
# ...                                                 ...
# 1958                                                 14
# 1959                                                 14
# 1960                                                 14
# 1961                                                 14
# 1962                                                 14
#
#      Days Since Last Cleaning  \
# 0                           0
# 1                           1
# 2                           2
# 3                           3
# 4                           4
# ...                       ...
# 1958                      146
# 1959                      147
# 1960                      148
# 1961                      149
# 1962                      150
#
#      Vessel External Conditions Wind Relative Angle (degrees)  \
# 0                                            205.243173
# 1                                            205.243173
# 2                                            205.243173
# 3                                            205.243173
# 4                                            205.243173
# ...                                                 ...
# 1958                                         205.243173
# 1959                                         205.243173
# 1960                                         205.243173
# 1961                                         205.243173
# 1962                                         205.243173
#
#      Vessel External Conditions Wind Relative Speed (knots)  \
# 0                                             21.467125
# 1                                             21.467125
# 2                                             21.467125
# 3                                             21.467125
# 4                                             21.467125
# ...                                                 ...
# 1958                                          21.467125
# 1959                                          21.467125
# 1960                                          21.467125
# 1961                                          21.467125
# 1962                                          21.467125
#
#      Vessel External Conditions Sea Water Temperature (Provider S)  \
# 0                                             24.299006
# 1                                             24.299006
# 2                                             24.299006
# 3                                             24.299006
# 4                                             24.299006
# ...                                                 ...
# 1958                                          24.299006
# 1959                                          24.299006
# 1960                                          24.299006
# 1961                                          24.299006
# 1962                                          24.299006
#
#      Vessel External Conditions Wave Significant Height (Provider MB)  \
# 0                                              2.012381
# 1                                              2.012381
# 2                                              2.012381
# 3                                              2.012381
# 4                                              2.012381
# ...                                                 ...
# 1958                                           2.012381
# 1959                                           2.012381
# 1960                                           2.012381
# 1961                                           2.012381
# 1962                                           2.012381
#
#       Predicted Shaft Power
# 0                  1.910755
# 1                  1.910755
# 2                  1.910755
# 3                  1.910755
# 4                  1.910755
# ...                     ...
# 1958               1.958133
# 1959               1.958133
# 1960               1.958133
# 1961               1.958133
# 1962               1.958133
#
# [1963 rows x 9 columns]

# %%
speed_col = "Vessel Hull Through Water Longitudinal Speed (knots)"

# 1) Predict the coefficient (no speed in features)
expected_features = [f for f in all_predictive_variables if f != speed_col]
pred_coeff = gam_pipeline.predict(simulation_df[expected_features])

# 2) Back-transform to kW using the speed for each row
speed_vals = simulation_df[speed_col].to_numpy()
simulation_df['Predicted Shaft Power'] = pred_coeff * (speed_vals ** 3)

# Set a nice color palette for the different speeds
unique_speeds = sorted(simulation_df['Vessel Hull Through Water Longitudinal Speed (knots)'].unique())
colors = sns.color_palette("viridis", len(unique_speeds))

plt.figure(figsize=(12, 7))

# Plot one line for each Speed
for i, speed in enumerate(unique_speeds):
    # Filter the dataframe for this specific speed
    subset = simulation_df[simulation_df['Vessel Hull Through Water Longitudinal Speed (knots)'] == speed]
    
    # Plot Days vs Predicted Power
    plt.plot(
        subset['Days Since Last Cleaning'], 
        subset['Predicted Shaft Power'], 
        linewidth=2.5, 
        color=colors[i],
        label=f"{speed} knots"
    )

# Formatting
plt.title("Expected Shaft Power vs. Days Since Cleaning (at various speeds)", fontsize=16)
plt.xlabel("Days Since Last Cleaning", fontsize=14)
plt.ylabel("Predicted Shaft Power (kW)", fontsize=14)
plt.xlim(0, 150)

# Add a legend to show which line is which speed
plt.legend(title="Speed Through Water", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True, alpha=0.3)
plt.tight_layout() # Ensures the legend isn't cut off
plt.show()

# %% [markdown]
# ### 3.3.3. Speed through water

# %% [markdown]
# #### 3.3.3.1. Speed/power curve

# %%
speed_idx = all_predictive_variables.index("Vessel Hull Through Water Longitudinal Speed (knots)")
print(f"Speed is at index: {speed_idx}")

# 2. Generate a perfectly spaced grid of 100 points for the speed feature
# This creates a synthetic array where ONLY the speed feature changes.
XX = actual_pygam_model.generate_X_grid(term=speed_idx)

# 3. Extract the partial dependence (the isolated kW penalty) and the 95% confidence intervals
pdep, confi = actual_pygam_model.partial_dependence(term=speed_idx, X=XX, width=0.95)

# 4. We only want to plot the X-axis for the speed variable itself
x_axis_values = XX[:, speed_idx]

# 2. Unscale the grid points so the X-axis is back in real "Days"
XX_unscaled = scaler.inverse_transform(XX)
real_speed = XX_unscaled[:, speed_idx]

# 3. Filter to only include days up to 160
mask = real_speed <= 160
real_speed_filtered = real_speed[mask]
pdep_filtered = pdep[mask]
confi_filtered = confi[mask]

# 4. Plot the final, isolated Speed Curve
plt.figure(figsize=(10, 6))

plt.plot(real_speed, pdep, color='darkblue', linewidth=2.5, label='Isolated Speed Penalty')
plt.fill_between(real_speed, confi[:, 0], confi[:, 1], color='cornflowerblue', alpha=0.3, label='95% Confidence Interval')

plt.title("Isolated Impact of Speed Through Water on Shaft Power", fontsize=14)
plt.xlabel("Speed Through Water (knots)", fontsize=12) 
plt.ylabel("Excess Shaft Power (kW)", fontsize=12)
plt.axhline(y=0, color='red', linestyle='--', linewidth=1)

plt.xlim(real_speed.min(), real_speed.max()) 

plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# Speed is at index: 2
